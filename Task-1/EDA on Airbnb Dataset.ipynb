# %% [markdown]
# ### EDA on Airbnb Dataset

# %% [markdown]
# Step 1 : Importing Required Libraries

# %%
# Importing Necessary Libraries :
''' Import all of the libraries needed for our investigation, including those for data 
loading, statistical analysis, visualizations, univariate and bivariate analysis, etc.'''

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Step 2 : Reading the Dataset

# %%
# loading and reading the Dataset :

Airbnb = pd.read_excel("Airbnb_Excel.xls")
Airbnb.head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
#
#    calculated host listings count  availability 365  \
# 0                             6.0             286.0
# 1                             2.0             228.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
#
# [2 rows x 26 columns]

# %%
# Making a Copy of the Dataset :
'''When performing data manipulation or preprocessing, it is a good practice to create a copy
of the original dataset. This ensures the original data remains unaltered and can be referred
to later if needed.'''

Airbnb_copy = Airbnb.copy()

# %% [markdown]
# Step 3 : Analyzing the Data

# %%
# Shape of the data :
'''shape will show how many features (columns) and observations (rows) there are in the
dataset.'''

Airbnb_copy.shape
# Out:
# (65535, 26)

# %%
#Data information :
'''info() facilitates comprehension of the data type and related information, such as the 
quantity of records in each column, whether the data is null or not, the type of data, 
and the dataset’s memory use.'''

Airbnb_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              65535 non-null  int64
#  1   NAME                            65322 non-null  object
#  2   host id                         65535 non-null  int64
#  3   host_identity_verified          65318 non-null  object
#  4   host name                       65256 non-null  object
#  5   neighbourhood group             65506 non-null  object
#  6   neighbourhood                   65519 non-null  object
#  7   lat                             65527 non-null  float64
#  8   long                            65527 non-null  float64
#  9   country                         65212 non-null  object
#  10  country code                    65449 non-null  object
#  11  instant_bookable                65449 non-null  float64
#  12  cancellation_policy             65478 non-null  object
#  13  room type                       65535 non-null  object
#  14  Construction year               65345 non-null  float64
#  15  price                           65395 non-null  float64
#  16  service fee                     65395 non-null  float64
#  17  minimum nights                  65172 non-null  float64
#  18  number of reviews               65384 non-null  float64
#  19  last review                     54828 non-null  datetime64[ns]
#  20  reviews per month               54842 non-null  float64
#  21  review rate number              65303 non-null  float64
#  22  calculated host listings count  65391 non-null  float64
#  23  availability 365                65097 non-null  float64
#  24  house_rules                     30835 non-null  object
#  25  license                         1 non-null      object
# dtypes: datetime64[ns](1), float64(12), int64(2), object(11)
# memory usage: 13.0+ MB

# %%
# Describing the data :
'''The DataSet Airbnb_copy is statistically summarized by the code Airbnb_copy.describe(),
which gives the count, mean, standard deviation, minimum, and quartiles for each 
numerical column. The dataset’s central tendencies and spread are briefly summarized.'''

Airbnb_copy.describe()
# Out:
#                  id       host id           lat          long  \
# count  6.553500e+04  6.553500e+04  65527.000000  65527.000000
# mean   1.909855e+07  4.934362e+10     40.728097    -73.949317
# min    1.001254e+06  1.303496e+08     40.499790    -74.249840
# 25%    1.004994e+07  2.466406e+10     40.688620    -73.982920
# 50%    1.909855e+07  4.920622e+10     40.722610    -73.954560
# 75%    2.814716e+07  7.413195e+10     40.762790    -73.931805
# max    3.719576e+07  9.876313e+10     40.916970    -73.705220
# std    1.044867e+07  2.853736e+10      0.055913      0.050248
#
#        instant_bookable  Construction year         price   service fee  \
# count      65449.000000       65345.000000  65395.000000  65395.000000
# mean           0.496555        2012.490688    624.246104    124.809160
# min            0.000000        2003.000000     50.000000     10.000000
# 25%            0.000000        2008.000000    337.000000     67.000000
# 50%            0.000000        2012.000000    624.000000    125.000000
# 75%            1.000000        2017.000000    912.000000    182.000000
# max            1.000000        2022.000000   1200.000000    240.000000
# std            0.499992           5.761357    331.741967     66.338849
#
#        minimum nights  number of reviews                    last review  \
# count    65172.000000       65384.000000                          54828
# mean         8.080479          27.803591  2019-09-14 14:26:50.505581056
# min      -1223.000000           0.000000            2012-07-11 00:00:00
# 25%          1.000000           1.000000            2019-01-01 00:00:00
# 50%          3.000000           7.000000            2019-06-21 00:00:00
# 75%          5.000000          29.000000            2021-10-11 00:00:00
# max       5645.000000        1024.000000            2058-06-16 00:00:00
# std         34.916828          52.175852                            NaN
#
#        reviews per month  review rate number  calculated host listings count  \
# count       54842.000000        65303.000000                    65391.000000
# mean            1.435170            3.313937                        8.829763
# min             0.010000            1.000000                        1.000000
# 25%             0.250000            2.000000                        1.000000
# 50%             0.830000            3.000000                        1.000000
# 75%             2.070000            4.000000                        3.000000
# max            90.000000            5.000000                      332.000000
# std             1.820707            1.264292                       34.583051
#
#        availability 365
# count      65097.000000
# mean         156.357620
# min          -10.000000
# 25%           22.000000
# 50%          133.000000
# 75%          285.000000
# max          426.000000
# std          134.407611

# %%
# Column to list :
'''The code Airbnb_copy.columns.tolist() converts the column names of the DataSet ‘Airbnb_copy’ into a 
Python list, providing a convenient way to access and manipulate column names.'''

Airbnb_copy.columns.tolist()
# Out:
# ['id',
#  'NAME',
#  'host id',
#  'host_identity_verified',
#  'host name',
#  'neighbourhood group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room type',
#  'Construction year',
#  'price',
#  'service fee',
#  'minimum nights',
#  'number of reviews',
#  'last review',
#  'reviews per month',
#  'review rate number',
#  'calculated host listings count',
#  'availability 365',
#  'house_rules',
#  'license']

# %%
# Re-naming the Columns And Verifying :
'''When column names contain spaces, it is recommended to remove or replace the spaces 
with underscores. This helps to avoid errors or syntax issues during operations like 
missing value treatment or data manipulation'''

Airbnb_copy.columns = Airbnb_copy.columns.str.replace(' ', '_')
Airbnb_copy.columns.tolist()
# Out:
# ['id',
#  'NAME',
#  'host_id',
#  'host_identity_verified',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country_code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room_type',
#  'Construction_year',
#  'price',
#  'service_fee',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'review_rate_number',
#  'calculated_host_listings_count',
#  'availability_365',
#  'house_rules',
#  'license']

# %%
# Checking for the duplicate values :
'''To ensure the data is free from redundancy, we need to check for any duplicate rows 
across all columns (Numerical, Categorical, and Datetime). Identifying duplicates
allows us to assess the quality of the data and take appropriate action, such as 
removing or handling these duplicates to maintain data integrity.'''

Airbnb_copy.duplicated().sum()
# Out:
# 0

# %%
# Checking for Missing values :
'''The code Airbnb_copy.isnull().sum() checks for missing values in each column of the DataSet
‘Airbnb_copy’ and returns the sum of null values for each column'''

Airbnb_copy.isnull().sum()
# Out:
# id                                    0
# NAME                                213
# host_id                               0
# host_identity_verified              217
# host_name                           279
# neighbourhood_group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                             323
# country_code                         86
# instant_bookable                     86
# cancellation_policy                  57
# room_type                             0
# Construction_year                   190
# price                               140
# service_fee                         140
# minimum_nights                      363
# number_of_reviews                   151
# last_review                       10707
# reviews_per_month                 10693
# review_rate_number                  232
# calculated_host_listings_count      144
# availability_365                    438
# house_rules                       34700
# license                           65534
# dtype: int64

# %%
# Separating Date-time, Numerical and Categorical columns and Verifying :
'''Separating numerical and categorical columns is an essential step in data preprocessing
because the techniques used to analyze, process, and impute these data types are often
different'''

datetime_cols = Airbnb_copy.select_dtypes(include=['datetime']).columns
numerical_cols = Airbnb_copy.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = Airbnb_copy.select_dtypes(include=['object', 'category']).columns

# %%
datetime_cols
# Out:
# Index(['last_review'], dtype='object')

# %%
numerical_cols
# Out:
# Index(['id', 'host_id', 'lat', 'long', 'instant_bookable', 'Construction_year',
#        'price', 'service_fee', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
categorical_cols
# Out:
# Index(['NAME', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'country', 'country_code', 'cancellation_policy',
#        'room_type', 'house_rules', 'license'],
#       dtype='object')

# %%
# Replacing Missing Values with Statistical Measures and Verifying :
''' For Datetime Data: Impute missing values with the median date. This can be useful
when working with datetime columns that may have missing timestamps.'''

for col in datetime_cols:
    Airbnb_copy[col].fillna(Airbnb_copy[col].median(), inplace=True)

'''For Numerical Data: Impute missing values with the median. This is useful when the 
data is skewed, as the median is less sensitive to outliers compared to the mean.'''

for col in numerical_cols:
    Airbnb_copy[col].fillna(Airbnb_copy[col].median(), inplace=True)
    
'''For Categorical Data: Impute missing values with the mode (the most frequent value). 
This is often used when dealing with categorical variables to fill in missing data with
the most common category.'''

for col in categorical_cols:
    Airbnb_copy[col].fillna(Airbnb_copy[col].mode()[0], inplace=True)

Airbnb_copy.isnull().sum()
# Out:
# id                                0
# NAME                              0
# host_id                           0
# host_identity_verified            0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# lat                               0
# long                              0
# country                           0
# country_code                      0
# instant_bookable                  0
# cancellation_policy               0
# room_type                         0
# Construction_year                 0
# price                             0
# service_fee                       0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# review_rate_number                0
# calculated_host_listings_count    0
# availability_365                  0
# house_rules                       0
# license                           0
# dtype: int64

# %% [markdown]
#  Univariate Analysis (Analyzing individual columns)

# %%
#Distribution of numerical variables:
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = Airbnb_copy.select_dtypes(include=['int64', 'float64']).columns
for col in numerical_cols:
    plt.figure(figsize=(9, 3))
    sns.histplot(Airbnb_copy[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
#Distribution of categorical variables:
#categorical_cols = Airbnb_copy.select_dtypes(include='object').columns
'''for col in categorical_cols:
    plt.figure(figsize=(20, 3))
    sns.countplot(data=Airbnb_copy, x=col)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()'''
# Out:
# "for col in categorical_cols:\n    plt.figure(figsize=(20, 3))\n    sns.countplot(data=Airbnb_copy, x=col)\n    plt.title(f'Distribution of {col}')\n    plt.xlabel(col)\n    plt.ylabel('Count')\n    plt.xticks(rotation=45)\n    plt.show()"

# %%
#Outlier detection:
Airbnb_copy[numerical_cols].columns
# Out:
# Index(['id', 'host_id', 'lat', 'long', 'instant_bookable', 'Construction_year',
#        'price', 'service_fee', 'minimum_nights', 'number_of_reviews',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
for i in Airbnb_copy[numerical_cols].columns:
    plt.figure(figsize=(10,0.5))
    sns.boxplot(x=Airbnb_copy[i])
    plt.title(i)
    plt.show()

# %%
#Handling Outliers:
'''We will create a user-defined function to calculate the upper and lower cutoff values 
needed for the IQR method.Then, we will use the clip function to handle and remove the 
outliers effectively.'''

def outliertreat_IQR(d):
    m = d.quantile(0.5)
    q1 = d.quantile(0.25)
    q3 = d.quantile(0.75)
    q_1p = d.quantile(0.01)
    q_99p = d.quantile(0.99)
    iqr = q3 - q1
    lc = q1 - 1.5*iqr
    uc = q3 + 1.5*iqr
    return lc,uc

# %%
Airbnb_copy[numerical_cols].apply(outliertreat_IQR)
# Out:
#            id       host_id       lat       long  instant_bookable  \
# 0 -17095878.0 -4.953776e+10  40.57739 -74.059572              -1.5
# 1  55292978.0  1.483338e+11  40.87403 -73.855153               2.5
#
#    Construction_year   price  service_fee  minimum_nights  number_of_reviews  \
# 0             1994.5  -521.5       -103.0            -5.0              -41.0
# 1             2030.5  1770.5        353.0            11.0               71.0
#
#    reviews_per_month  review_rate_number  calculated_host_listings_count  \
# 0             -1.885                -1.0                            -2.0
# 1              3.995                 7.0                             6.0
#
#    availability_365
# 0            -368.5
# 1             675.5

# %%
Airbnb_copy['lat'] = Airbnb_copy.lat.clip(lower = 40.57739, upper = 40.87403)
Airbnb_copy['long'] = Airbnb_copy.long.clip(lower = -74.059572, upper = -73.855153)
Airbnb_copy['minimum_nights'] = Airbnb_copy.minimum_nights.clip(lower = -0.5, upper = 11.0)
Airbnb_copy['number_of_reviews'] = Airbnb_copy.number_of_reviews.clip(lower = -41, upper = 71)
Airbnb_copy['reviews_per_month'] = Airbnb_copy.reviews_per_month.clip(lower = -1.885, upper = 3.995)
Airbnb_copy['calculated_host_listings_count'] = Airbnb_copy.calculated_host_listings_count.clip(lower = -2.0, upper = 6)

# %%
for i in Airbnb_copy[numerical_cols].columns:
    plt.figure(figsize=(10,0.5))
    sns.boxplot(x=Airbnb_copy[i])
    plt.title(i)
    plt.show()

# %%
Airbnb_copy.to_csv("Cleaned_Airbnb_dataset.csv")
